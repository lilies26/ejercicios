# %% [markdown]
# ## Problema: Cálculo de Interés Simple
# Escribe un programa que calcule el interés simple ganado en una inversión. El programa debe solicitar al usuario el capital invertido (en pesos), la tasa de interés anual (como porcentaje), y el número de años que durará la inversión. El programa debe calcular y mostrar el interés simple utilizando la fórmula:
#
# $Interés=Capital \times Tasa \times Tiempo$
#
# Respuesta esperada: Un valor numérico que representa el interés simple ganado.

# %%
Capital_invertido=float(input("Ingrese el capital inveretido"))
interes_anual=[]
bucle=1
while bucle:
     valor=float(input("ingrese la tasa de interes anual ejemplo: 5%"))
     if valor>=0 and valor<=100:
         tasa=valor/100
         tiempo=int(input("cuanto tiempo durara la inversion (en anos):"))
         interes=Capital_invertido*tasa*tiempo
         print(f"el interes ganado es: {interes}")
         bucle=0
     else:
       print("Ingrese un valor valido entre 0 y 100")
# Out:
# Ingrese el capital inveretido34
# ingrese la tasa de interes anual ejemplo: 5%60
# cuanto tiempo durara la inversion (en anos):8.8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-3be3a7d23c1f> in <cell line: 4>()
#       6      if valor>=0 and valor<=100:
#       7          tasa=valor/100
# ----> 8          tiempo=int(input("cuanto tiempo durara la inversion (en anos):"))
#       9          interes=Capital_invertido*tasa*tiempo
#      10          print(f"el interes ganado es: {interes}")
#
# ValueError: invalid literal for int() with base 10: '8.8'

# %%
Capital_invertido=float(input("Ingrese el capital inveretido"))
interes_anual=[]

while 1:
     valor=float(input("ingrese la tasa de interes anual ejemplo: 5%"))
     if valor>=0 and valor<=100:
         tasa=valor/100
         tiempo=int(input("cuanto tiempo durara la inversion (en anos):"))
         interes=Capital_invertido*tasa*tiempo
         print(f"el interes ganado es:{interes}")
         break
     else:
       print("Ingrese un valor valido entre 0 y 100")
# Out:
# Ingrese el capital inveretido100
# ingrese la tasa de interes anual ejemplo: 5%600
# Ingrese un valor valido entre 0 y 100
# ingrese la tasa de interes anual ejemplo: 5%7
# cuanto tiempo durara la inversion (en anos):90
# el interes ganado es:630.0000000000001

# %%
while True:
     while True:
         try:
             valor=float(input("ingrese la tasa de interes anual ejemplo: 5%"))
             break
         except ValueError:
             print("ingrese un numero")
     if valor>=0 and valor<=100:
         tasa=valor/100
         while True:
             try:
                 tiempo=int(input("cuanto tiempo durara la inversion (en anos):"))
                 while True:
                     try:
                         Capital_invertido=float(input("Ingrese el capital inveretido en pesos"))
                         interes=Capital_invertido*tasa*tiempo
                         break
                     except ValueError:
                         print("ingrese un numero")
                 break
             except ValueError:
                 print("ingrese un numero entero de anos")

         print(f"el interes ganado es: {interes}")
         break

     else: print("Ingrese un valor valido entre 0 y 100")
# Out:
# ingrese la tasa de interes anual ejemplo: 5%5
# cuanto tiempo durara la inversion (en anos):5
# Ingrese el capital inveretido en pesos5
# el interes ganado es: 1.25

# %%
while True:
                     try:
                         Capital_invertido=float(input("Ingrese el capital inveretido en pesos"))
                         break
                     except ValueError:
                         print("ingrese un numero")
while True:
             try:
                 tiempo=int(input("cuanto tiempo durara la inversion (en anos):"))

                 break
             except ValueError:
                 print("ingrese un numero entero de anos")
while True:
     while True:
         try:
             valor=float(input("ingrese la tasa de interes anual ejemplo: 5%"))
             break
         except ValueError:
             print("ingrese un numero")
     if valor>=0 and valor<=100:
         tasa=valor/100
         interes=Capital_invertido*tasa*tiempo

         print(f"el interes ganado es: {interes}")
         break

     else: print("Ingrese un valor valido entre 0 y 100")
# Out:
# Ingrese el capital inveretido en pesosjo
# ingrese un numero
# Ingrese el capital inveretido en pesosjo
# ingrese un numero
# Ingrese el capital inveretido en pesos69
# cuanto tiempo durara la inversion (en anos):nl
# ingrese un numero entero de anos
# cuanto tiempo durara la inversion (en anos):67
# ingrese la tasa de interes anual ejemplo: 5%300
# Ingrese un valor valido entre 0 y 100
# ingrese la tasa de interes anual ejemplo: 5%no
# ingrese un numero
# ingrese la tasa de interes anual ejemplo: 5%399
# Ingrese un valor valido entre 0 y 100
# ingrese la tasa de interes anual ejemplo: 5%20
# el interes ganado es: 924.6
